# %% [markdown]
# # Assignment #4: Extracting syntactic groups using machine-learning techniques
# Author: Pierre Nugues

# %% [markdown]
# In this assignment, you will create a system to extract syntactic groups from a text. You will apply it to the CoNLL 2000 dataset. In addition, you will try to link a few extracted named entities to real things using wikipedia.

# %% [markdown]
# ## Objectives

# %% [markdown]
# The objectives of this assignment are to:
# * Write a program to detect partial syntactic structures
# * Extract named entities and link them to real things using Wikipedia
# * Understand the principles of supervised machine learning techniques applied to language processing
# * Use a popular machine learning toolkit: scikit-learn
# * Write a short report of 2 to 3 pages on the assignment

# %% [markdown]
# ## Choosing a training and a test sets

# %% [markdown]
# * As annotated data and annotation scheme, you will use the data available from [CoNLL 2000](https://www.clips.uantwerpen.be/conll2000/chunking/).
# * Download both the training and test sets and decompress them.
# * Local copies are also available here: [train.txt](https://fileadmin.cs.lth.se/cs/Education/EDAN20/corpus/conll2000/train.txt) and [test.txt](https://fileadmin.cs.lth.se/cs/Education/EDAN20/corpus/conll2000/test.txt)
# * Read the description of the CoNLL 2000 task

# %% [markdown]
# ## Loading the corpus

# %% [markdown]
# ### The datasets

# %% [markdown]
# You may need to adjust the paths to load the datasets.

# %%
train_file = 'C:/Users/4stra/Documents/pyton/FDAN20/env/edan20/notebooks/train.txt'
test_file = 'C:/Users/4stra/Documents/pyton/FDAN20/env/edan20/notebooks/test.txt'

# %% [markdown]
# #### Reading the files

# %% [markdown]
# Read the functions below to load the datasets. They store the corpus in a list of sentences. Each sentence is a list of rows, where each row is a dictionary.

# %%
def read_sentences(file):
    """
    Creates a list of sentences from the corpus
    Each sentence is a string
    :param file:
    :return:
    """
    f = open(file).read().strip()
    sentences = f.split('\n\n')
    return sentences

# %%
def split_rows(sentences, column_names):
    """
    Creates a list of sentence where each sentence is a list of lines
    Each line is a dictionary of columns
    :param sentences:
    :param column_names:
    :return:
    """
    new_sentences = []
    for sentence in sentences:
        rows = sentence.split('\n')
        sentence = [dict(zip(column_names, row.split())) for row in rows]
        new_sentences.append(sentence)
    return new_sentences

# %% [markdown]
# ### Loading dictionaries

# %% [markdown]
# The CoNLL 2000 files have three columns

# %%
column_names = ['form', 'pos', 'chunk']

# %% [markdown]
# We load the corpus

# %%
train_sentences = read_sentences(train_file)
train_corpus = split_rows(train_sentences, column_names)
train_corpus[:2]
# Out:
# [[{'form': 'Confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'widely', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'dive', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'due', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'release', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'tomorrow', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'fail', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'near-record', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'deficits', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Chancellor', 'pos': 'NNP', 'chunk': 'O'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'Exchequer', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Nigel', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'restated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'commitment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'firm', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'helped', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'prevent', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'freefall', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'over', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'past', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'week', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %% [markdown]
# ## Baseline chunker

# %% [markdown]
# Most statistical algorithms for language processing start with a so-called baseline. The baseline performance corresponds to the application of a minimal technique that is used to assess the difficulty of a task and for comparison with further programs.
#
# You will implement the baseline proposed by the organizers of the
#         <a href="https://www.clips.uantwerpen.be/conll2000/chunking/">CoNLL 2000 shared task</a>, Sect. <i>Results</i>.
# 1. Read it;
# 2. In the report you will tell what do you think of it.

# %% [markdown]
# ### Auxiliary functions

# %% [markdown]
# A function to count the parts of speech

# %%
def count_pos(corpus):
    """
    Computes the part-of-speech distribution
    in a CoNLL 2000 file
    :param corpus:
    :return:
    """
    pos_cnt = {}
    for sentence in corpus:
        for row in sentence:
            if row['pos'] in pos_cnt:
                pos_cnt[row['pos']] += 1
            else:
                pos_cnt[row['pos']] = 1
    return pos_cnt

# %% [markdown]
# We first collect all the parts of speech and we count them.

# %%
pos_cnt = count_pos(train_corpus)
pos_cnt
# Out:
# {'NN': 30147,
#  'IN': 22764,
#  'DT': 18335,
#  'VBZ': 4648,
#  'RB': 6607,
#  'VBN': 4763,
#  'TO': 5081,
#  'VB': 6017,
#  'JJ': 13085,
#  'NNS': 13619,
#  'NNP': 19884,
#  ',': 10770,
#  'CC': 5372,
#  'POS': 1769,
#  '.': 8827,
#  'VBP': 2868,
#  'VBG': 3272,
#  'PRP$': 1881,
#  'CD': 8315,
#  '``': 1531,
#  "''": 1493,
#  'VBD': 6745,
#  'EX': 206,
#  'MD': 2167,
#  '#': 36,
#  '(': 274,
#  '$': 1750,
#  ')': 281,
#  'NNPS': 420,
#  'PRP': 3820,
#  'JJS': 374,
#  'WP': 529,
#  'RBR': 321,
#  'JJR': 853,
#  'WDT': 955,
#  'WRB': 478,
#  'RBS': 191,
#  'PDT': 55,
#  'RP': 83,
#  ':': 1047,
#  'FW': 38,
#  'WP$': 35,
#  'SYM': 6,
#  'UH': 15}

# %% [markdown]
# ### Chunk distribution

# %% [markdown]
# You will compute the chunk distribution for each part of speech. You will use the training file to derive the distribution and you will store the results in a dictionary. Below, you have an excerpt of the expected results:
# ```
# {'JJR':
# {'I-ADVP': 17, 'I-ADJP': 45, 'I-NP': 204, 'B-ADVP': 63,
# 'B-PP': 2, 'B-ADJP': 111, 'B-NP': 382, 'B-VP': 2,
# 'I-VP': 11, 'O': 16},
# 'CC':
# {'B-ADVP': 3, 'O': 3676, 'I-VP': 104, 'B-CONJP': 6,
# 'I-ADVP': 30, 'I-UCP': 2, 'I-PP': 24, 'I-ADJP': 26,
# 'I-NP': 1409, 'B-ADJP': 2, 'B-NP': 18, 'B-PP': 70,
# 'I-PRT': 1, 'B-VP': 1},
# 'NN':
# {'B-LST': 2, 'I-INTJ': 2, 'B-ADVP': 38, 'O': 37,
# 'I-ADVP': 11, 'B-INTJ': 1, 'I-UCP': 2, 'B-UCP': 2,
# 'I-VP': 77, 'B-PRT': 2, 'I-ADJP': 41, 'I-NP': 24456,
# 'B-ADJP': 44, 'B-NP': 5160, 'B-PP': 15, 'B-VP': 257},
# ...
# ```

# %%
chunk_dist={}

for sen in train_corpus:
    for rad in sen:
        if rad['pos'] in chunk_dist.keys():
            if rad['chunk'] in chunk_dist[rad['pos']].keys():
                chunk_dist[rad['pos']][rad['chunk']] +=1
            else:
                 chunk_dist[rad['pos']][rad['chunk']] =1 
        else:
            chunk_dist[rad['pos']]={rad['chunk']:1}

# %%
chunk_dist['NN']
# Out:
# {'B-NP': 5160,
#  'I-NP': 24456,
#  'B-VP': 257,
#  'B-ADJP': 44,
#  'B-ADVP': 38,
#  'O': 37,
#  'B-PP': 15,
#  'I-ADVP': 11,
#  'I-ADJP': 41,
#  'I-VP': 77,
#  'B-INTJ': 1,
#  'B-LST': 2,
#  'B-UCP': 2,
#  'I-UCP': 2,
#  'B-PRT': 2,
#  'I-INTJ': 2}

# %% [markdown]
# ### Selecting the POS-chunk associations

# %% [markdown]
# For each part of speech, select the best association. In the example above, you will have (NN, I-NP) as it is the most frequent. You will store the results in a dictionary that you will call `pos_chunk`

# %%
pos_chunk={}
for poss in chunk_dist:
    max_chunk=max(chunk_dist[poss],key=chunk_dist[poss].get)
    pos_chunk[poss]=max_chunk

# %%
pos_chunk['NN']
# Out:
# 'I-NP'

# %% [markdown]
# ### Prediction

# %% [markdown]
# Using the resulting associations, apply your chunker to the test file. You will write a `predict(model, corpus)` function, where `model` will be your associations and `corpus`, the test corpus. You will format the test corpus as a dictionary, where you will add a `pchunk` key for each row with a value that will correspond to the predicted chunk.

# %%
def predict(model,cor):
    for sen in cor:
        for rad in sen:
            typnn=rad['pos']
            enannan=model[typnn]
            rad['pchunk']=enannan
    return cor

# %% [markdown]
# We load the test corpus

# %%
test_sentences = read_sentences(test_file)
test_corpus = split_rows(test_sentences, column_names)
test_corpus[:1]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %% [markdown]
# We predict the groups. You should have added a `pchunk` key

# %%
predicted_test_corpus = predict(pos_chunk, test_corpus)
predicted_test_corpus[:1]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'I-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'I-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP', 'pchunk': 'B-PP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP', 'pchunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP', 'pchunk': 'I-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O', 'pchunk': 'O'}]]

# %% [markdown]
# ### Accuracy

# %% [markdown]
# We can evaluate the performance of the baseline with the tag accuracy: the percentage of words that receive the correct tag.

# %%
def eval(predicted):
    """
    Evaluates the predicted chunk accuracy
    :param predicted:
    :return:
    """
    word_cnt = 0
    correct = 0
    for sentence in predicted:
        for row in sentence:
            word_cnt += 1
            if row['chunk'] == row['pchunk']:
                correct += 1
    return correct / word_cnt

# %%
accuracy = eval(predicted_test_corpus)
accuracy
# Out:
# 0.7729066846782194

# %% [markdown]
# ### The CoNLL evaluation

# %% [markdown]
# The accuracy is very misleading as it is biased by the most frequent tags. It is not a good way to evaluate chunking. Instead, CoNLL computes the F1 score of all the chunks with a specific evaluation script.

# %% [markdown]
# #### Saving the corpus

# %% [markdown]
# To use the CoNLL evaluation script, you will store your results in an output file that has four columns. The three first columns will be the input columns from the test file:
# * word,
# * part of speech, and
# * gold-standard chunk.
#
# You will append the predicted chunk as the 4th column. Your output file should look like the excerpt below:
# ```
# Rockwell NNP B-NP I-NP
# International NNP I-NP I-NP
# Corp. NNP I-NP I-NP
# 's POS B-NP B-NP
# Tulsa NNP I-NP I-NP
# unit NN I-NP I-NP
# said VBD B-VP B-VP
# it PRP B-NP B-NP
# ```
# The separator is the space.

# %% [markdown]
# You will use a `save_results(output_dict, keys, output_file)` function, where the keys will be `['form', 'pos', 'chunk', 'pchunk']`

# %%
keys = ['form', 'pos', 'chunk', 'pchunk']

# %%
def save_results(output_dict, keys, output_file):
    f_out = open(output_file, 'w')
    # We write the word (form), part of speech (pos),
    # gold-standard chunk (chunk), and predicted chunk (pchunk)
    for sentence in output_dict:
        for row in sentence:
            for key in keys:
                f_out.write(row[key] + ' ')
            f_out.write('\n')
        f_out.write('\n')
    f_out.close()
    return

# %%
save_results(predicted_test_corpus, keys, 'out')

# %% [markdown]
# The CoNLL 2000 evaluation script will use these two last columns, chunk and predicted chunk, to compute the performance.

# %% [markdown]
# ### Evaluation

# %% [markdown]
# To evaluate your results, you have two options:
# 1. Use the original conlleval script here:  <a href="https://www.clips.uantwerpen.be/conll2000/chunking/"><tt>conlleval.txt</tt></a>.
# 2. Use a Python translation of it.
#
# You will use the second option and you will describe the results you obtained in your report

# %% [markdown]
# #### The Python translation

# %% [markdown]
# Install the script with:
# ```
# pip install conlleval
# ```
# from https://github.com/kaniblu/conlleval
# and run the cell below

# %%
import conlleval
lines = open('out').read().splitlines()
res = conlleval.evaluate(lines)
baseline_score = res['overall']['chunks']['evals']['f1']

# %%
baseline_score
# Out:
# 0.770671072299583

# %% [markdown]
# ### The official script

# %% [markdown]
# You may want to double-check your results with the original CoNLL script. It is more complex to use however:
# * <tt>conlleval.txt</tt> is the official CoNLL Perl script. It expects the two last columns of the test set to be the manually assigned chunk (gold standard) and the predicted chunk.
# * <tt>conlleval.txt</tt> was written for Unix and if you run Windows, you will have to use a terminal command. In the File menu of the notebook, select New and then Terminal.
# * Start it like this: ` $ conlleval.txt <out` where the `out` file contains both the gold and predicted chunk tags. `conlleval.txt` is a Perl script.
# * Perl is installed on most Unix distributions. If it is not installed on your machine, you need to install it. Make also sure that you have the execution rights. Otherwise change them with: `$ chmod +x conlleval.txt`
# * The `conlleval.txt` script expects the new lines to be `\n` as in Unix. If you run your Python program on Windows, your new lines will be `\r\n`. To have the correct new lines, add this parameter to `open()`: `newline='\n’` like this: `f_out = open('out', ‘w’, newline='\n’)`
# * The complete description of the CoNLL 2000 evaluation script is available here: [https://www.clips.uantwerpen.be/conll2000/chunking/output.html](https://www.clips.uantwerpen.be/conll2000/chunking/output.html)

# %% [markdown]
# ## Using Machine Learning: A first ML program

# %% [markdown]
# In this exercise, you will apply and explore a machine-learning program.
#
# The program that won the CoNLL 2000 shared task (Kudoh and Matsumoto, 2000) used a window of five words around the chunk tag to identify, $c_i$. They built a feature vector consisting of:
# 1. The values of the five words in this window: $w_{i-2}, w_{i-1}, w_{i}, w_{i+1}, w_{i+2}$
# 2. The values of the five parts of speech in this window: $t_{i-2}, t_{i-1}, t_{i}, t_{i+1}, t_{i+2}$
# 3. The values of the two previous chunk tags in the first part of the window: $c_{i-2}, c_{i-1}$
#
# The two last parameters (3.) are said to be dynamic because the program computes them at run-time. Read [Kudoh and Matsumoto's paper](http://www.clips.uantwerpen.be/conll2000/pdf/14244kud.pdf) and the [Yamcha](http://www.chasen.org/~taku/software/yamcha/) software site.
#
# You will start with a given code that uses the two first sets of features (1. and 2.) and add yourself the last one (3.) to improve the performance of your chunker. Kudoh and Matsumoto trained a classifier based on support vector machines. You will use logistic regression.

# %% [markdown]
# ### Imports

# %%
import bs4
import os
import requests
from sklearn.feature_extraction import DictVectorizer
from sklearn import svm
from sklearn import linear_model
from sklearn import metrics
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
import time

# %% [markdown]
# ### Feature extraction

# %% [markdown]
# #### Functions

# %% [markdown]
# A first function to extract features from one sentence

# %%
def extract_features_sent_static(sentence, w_size, feature_names):
    """
    Extract the features from one sentence
    returns X and y, where X is a list of dictionaries and
    y is a list of symbols
    :param sentence: string containing the CoNLL structure of a sentence
    :param w_size:
    :return:
    """

    # We pad the sentence to extract the context window more easily
    start = [{'form': 'BOS', 'pos': 'BOS', 'chunk': 'BOS'}]
    end = [{'form': 'EOS', 'pos': 'EOS', 'chunk': 'EOS'}]
    start *= w_size
    end *= w_size
    padded_sentence = start + sentence
    padded_sentence += end


    # We extract the features and the classes
    # X contains is a list of features, where each feature vector is a dictionary
    # y is the list of classes
    X = list()
    y = list()
    for i in range(len(padded_sentence) - 2 * w_size):
        # x is a row of X
        x = list()
        # The words in lower case
        for j in range(2 * w_size + 1):
             x.append(padded_sentence[i + j]['form'].lower())
        
        # The POS
        for j in range(2 * w_size + 1):
            x.append(padded_sentence[i + j]['pos'])
        # The chunks (Up to the word)
        """
        for j in range(w_size):
            x.append(padded_sentence[i + j]['chunk'])
        """
        # We represent the feature vector as a dictionary
        X.append(dict(zip(feature_names, x)))
        # The classes are stored in a list
        y.append(padded_sentence[i + w_size]['chunk'])
    return X, y

# %% [markdown]
# And from all the sentences

# %%
def extract_features_static(sentences, w_size, feature_names):
    """
    Builds X matrix and y vector
    X is a list of dictionaries and y is a list
    :param sentences:
    :param w_size:
    :return:
    """
    X_l = []
    y_l = []
    for sentence in sentences:
        X, y = extract_features_sent_static(sentence, w_size, feature_names)
        X_l.extend(X)
        y_l.extend(y)
    return X_l, y_l

# %% [markdown]
# #### Applying the feature extraction

# %% [markdown]
# The size of the window and the names of the features

# %%
w_size = 2  # The size of the context window to the left and right of the word lägg till word sen
feature_names = [ 'word_n2', 'word_n1',  'word', 'word_p1', 'word_p2','pos_n2', 'pos_n1', 'pos', 'pos_p1', 'pos_p2']

# %% [markdown]
# We read the corpus and format it as a dictionary

# %%
train_sentences = read_sentences(train_file)
train_corpus = split_rows(train_sentences, column_names)

# %%
train_corpus[:2]
# Out:
# [[{'form': 'Confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'widely', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'dive', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'due', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'release', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'tomorrow', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'fail', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'near-record', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'deficits', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Chancellor', 'pos': 'NNP', 'chunk': 'O'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'Exchequer', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Nigel', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'restated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'commitment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'firm', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'helped', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'prevent', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'freefall', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'over', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'past', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'week', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %%
X_dict, y = extract_features_static(train_corpus, w_size, feature_names)
X_dict[:2]
# Out:
# [{'word_n2': 'bos',
#   'word_n1': 'bos',
#   'word': 'confidence',
#   'word_p1': 'in',
#   'word_p2': 'the',
#   'pos_n2': 'BOS',
#   'pos_n1': 'BOS',
#   'pos': 'NN',
#   'pos_p1': 'IN',
#   'pos_p2': 'DT'},
#  {'word_n2': 'bos',
#   'word_n1': 'confidence',
#   'word': 'in',
#   'word_p1': 'the',
#   'word_p2': 'pound',
#   'pos_n2': 'BOS',
#   'pos_n1': 'NN',
#   'pos': 'IN',
#   'pos_p1': 'DT',
#   'pos_p2': 'NN'}]

# %%
y[:2]
# Out:
# ['B-NP', 'B-PP']

# %% [markdown]
# ### Feature encoding

# %%
# Vectorize the feature matrix and carry out a one-hot encoding
vec = DictVectorizer(sparse=True)
X = vec.fit_transform(X_dict)

# %% [markdown]
# ### Training the model

# %%
classifier = linear_model.LogisticRegression()
model = classifier.fit(X, y)
model
# Out:
# C:\Users\4stra\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### Predicting the test set

# %% [markdown]
# We read the sentences and create a dictionary

# %%
test_sentences = read_sentences(test_file)
test_corpus = split_rows(test_sentences, column_names)
test_corpus[:2]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'calls', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'supply', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': '200', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'additional', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'so-called', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'shipsets', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'planes', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %% [markdown]
# We extract the features

# %%
X_test_dict, y_test = extract_features_static(test_corpus, w_size, feature_names)
X_test_dict[:2]
# Out:
# [{'word_n2': 'bos',
#   'word_n1': 'bos',
#   'word': 'rockwell',
#   'word_p1': 'international',
#   'word_p2': 'corp.',
#   'pos_n2': 'BOS',
#   'pos_n1': 'BOS',
#   'pos': 'NNP',
#   'pos_p1': 'NNP',
#   'pos_p2': 'NNP'},
#  {'word_n2': 'bos',
#   'word_n1': 'rockwell',
#   'word': 'international',
#   'word_p1': 'corp.',
#   'word_p2': "'s",
#   'pos_n2': 'BOS',
#   'pos_n1': 'NNP',
#   'pos': 'NNP',
#   'pos_p1': 'NNP',
#   'pos_p2': 'POS'}]

# %%
y_test[:4]
# Out:
# ['B-NP', 'I-NP', 'I-NP', 'B-NP']

# %% [markdown]
# We vectorize the features

# %%
X_test = vec.transform(X_test_dict)  # Possible to add: .toarray()

# %% [markdown]
# And we predict the test set

# %%
y_test_predicted = classifier.predict(X_test)
y_test_predicted[:4]
# Out:
# array(['B-NP', 'I-NP', 'I-NP', 'B-NP'], dtype='<U7')

# %% [markdown]
# We now add the predicted chunks to the sentences

# %%
inx = 0
for sentence in test_corpus:
    for word in sentence:
        word['pchunk'] = y_test_predicted[inx]
        inx += 1

# %% [markdown]
# The index sould be equal to the length of the prediction

# %%
print(inx)
len(y_test_predicted)
# Out:
# 47377
# 47377

# %%
test_corpus[:2]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP', 'pchunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O', 'pchunk': 'O'}],
#  [{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'calls', 'pos': 'VBZ', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-SBAR', 'pchunk': 'B-SBAR'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'supply', 'pos': 'VB', 'chunk': 'I-VP', 'pchunk': 'I-VP'},
#   {'form': '200', 'pos': 'CD', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'additional', 'pos': 'JJ', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'so-called', 'pos': 'JJ', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'shipsets', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'planes', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O', 'pchunk': 'O'}]]

# %%
save_results(test_corpus, keys, 'out')

# %% [markdown]
# #### Evaluating the performance

# %%
lines = open('out').read().splitlines()
res = conlleval.evaluate(lines)
simple_ml_score = res['overall']['chunks']['evals']['f1']

# %%
simple_ml_score
# Out:
# 0.9157047482373494

# %% [markdown]
# ### Question on the ML program

# %% [markdown]
# 1. What is the feature vector that corresponds to the <tt>ml_chunker.py</tt> program? Is it the same Kudoh
#     and Matsumoto used in their experiment?
# 2. What is the performance of the chunker?
# 3. Remove the lexical features (the words) from the feature vector and measure the performance. You should
#     observe a decrease.
# 4. What is the classifier used in the program?
# 5. As an optional task, you may try two other classifiers from sklearn and measure their performance: decision trees, perceptron, support vector machines, etc. Be aware that support vector machines take a long time to train: up to one hour.

# %% [markdown]
# ## Using Machine Learning: Adding all the features from Kudoh and Matsumoto

# %% [markdown]
# Complement the feature vector used in the previous section with the two dynamic features, $c_{i-2}, c_{i-1}$, and train a new model. You will need to write a new `extract_features_sent_dyn` and `predict` functions.
# In his experiments, your teacher obtained a F1 score of 92.65 with logistic regression and the default parameters from sklearn, i.e. `linear_model.LogisticRegression()`;

# %% [markdown]
# **A frequent mistake in the labs** is to use the gold-standard chunks from the test set. Be aware that  when you predict the test set, you do not know the dynamic features in advance and you must  not use the ones from the test file. You will use the two previous chunk tags that you have predicted.

# %% [markdown]
# You need to reach a global F1 score of 92 to pass this laboratory.

# %%
### write your code here här slutade vi förra gången 

def extract_features_sent_dyn(sentence, w_size, feature_names):
    """
    Extract the features from one sentence
    returns X and y, where X is a list of dictionaries and
    y is a list of symbols
    :param sentence: string containing the CoNLL structure of a sentence
    :param w_size:
    :return:
    """

    # We pad the sentence to extract the context window more easily
    start = [{'form': 'BOS', 'pos': 'BOS', 'chunk': 'BOS'}]
    end = [{'form': 'EOS', 'pos': 'EOS', 'chunk': 'EOS'}]
    start *= w_size
    end *= w_size
    padded_sentence = start + sentence
    padded_sentence += end
    
    
    # We extract the features and the classes
    # X contains is a list of features, where each feature vector is a dictionary
    # y is the list of classes
    X = list()
    y = list()
    for i in range(len(padded_sentence) - 2 * w_size):
        # x is a row of X
        x = list()
        # The words in lower case
        for j in range(2 * w_size + 1):
            x.append(padded_sentence[i + j]['form'].lower())
        # The POS
        for j in range(2 * w_size + 1):
            x.append(padded_sentence[i + j]['pos'])
        # The chunks (Up to the word)
     
        for j in range(w_size):
            x.append(padded_sentence[i + j]['chunk'])
   
        # We represent the feature vector as a dictionary
        X.append(dict(zip(feature_names, x)))
        # The classes are stored in a list
        y.append(padded_sentence[i + w_size]['chunk'])

    return X, y

# %%
def extract_features_dyn(sentences, w_size, feature_names):
    """
    Builds X matrix and y vector
    X is a list of dictionaries and y is a list
    :param sentences:
    :param w_size:
    :return:
    """
    X_l = []
    y_l = []
    for sentence in sentences:
        X, y = extract_features_sent_dyn(sentence, w_size, feature_names)
        X_l.extend(X)
        y_l.extend(y)
    return X_l, y_l

# %%
feature_names_dyn = ['word_n2', 'word_n1', 'word', 'word_p1', 'word_p2',
                     'pos_n2', 'pos_n1', 'pos', 'pos_p1', 'pos_p2', 'chunk_n2',
                     'chunk_n1']

# %%
train_sentences = read_sentences(train_file)
train_corpus = split_rows(train_sentences, column_names)
train_corpus[:2]
# Out:
# [[{'form': 'Confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'widely', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'dive', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'due', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'release', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'tomorrow', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'fail', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'near-record', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'deficits', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Chancellor', 'pos': 'NNP', 'chunk': 'O'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'Exchequer', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Nigel', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'restated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'commitment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'firm', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'helped', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'prevent', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'freefall', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'over', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'past', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'week', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %%
X_dict, y = extract_features_dyn(train_corpus, w_size, feature_names_dyn)

# %%
X_dict[:3]
# Out:
# [{'word_n2': 'bos',
#   'word_n1': 'bos',
#   'word': 'confidence',
#   'word_p1': 'in',
#   'word_p2': 'the',
#   'pos_n2': 'BOS',
#   'pos_n1': 'BOS',
#   'pos': 'NN',
#   'pos_p1': 'IN',
#   'pos_p2': 'DT',
#   'chunk_n2': 'BOS',
#   'chunk_n1': 'BOS'},
#  {'word_n2': 'bos',
#   'word_n1': 'confidence',
#   'word': 'in',
#   'word_p1': 'the',
#   'word_p2': 'pound',
#   'pos_n2': 'BOS',
#   'pos_n1': 'NN',
#   'pos': 'IN',
#   'pos_p1': 'DT',
#   'pos_p2': 'NN',
#   'chunk_n2': 'BOS',
#   'chunk_n1': 'B-NP'},
#  {'word_n2': 'confidence',
#   'word_n1': 'in',
#   'word': 'the',
#   'word_p1': 'pound',
#   'word_p2': 'is',
#   'pos_n2': 'NN',
#   'pos_n1': 'IN',
#   'pos': 'DT',
#   'pos_p1': 'NN',
#   'pos_p2': 'VBZ',
#   'chunk_n2': 'B-NP',
#   'chunk_n1': 'B-PP'}]

# %% [markdown]
# You will now vectorize the training set

# %%
# Vectorize the feature matrix and carry out a one-hot encoding
vecc=DictVectorizer(sparse=True)
Xmat=vecc.fit_transform(X_dict)

# %% [markdown]
# And fit the model

# %%
clasifierr=linear_model.LogisticRegression()
model=clasifierr.fit(Xmat,y)
# Out:
# C:\Users\4stra\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model
# Out:
# LogisticRegression()

# %% [markdown]
# ### Prediction

# %% [markdown]
# You will finally predict the test set. We load the corpus again.

# %%
test_sentences = read_sentences(test_file)
test_corpus = split_rows(test_sentences, column_names)
test_corpus[:2]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'calls', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'supply', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': '200', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'additional', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'so-called', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'shipsets', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'planes', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %% [markdown]
# Let us extract the static features from one sentence

# %%
X_test_dict, y_test = extract_features_static([test_corpus[0]], w_size, feature_names)
X_test_dict[:2]
# Out:
# [{'word_n2': 'bos',
#   'word_n1': 'bos',
#   'word': 'rockwell',
#   'word_p1': 'international',
#   'word_p2': 'corp.',
#   'pos_n2': 'BOS',
#   'pos_n1': 'BOS',
#   'pos': 'NNP',
#   'pos_p1': 'NNP',
#   'pos_p2': 'NNP'},
#  {'word_n2': 'bos',
#   'word_n1': 'rockwell',
#   'word': 'international',
#   'word_p1': 'corp.',
#   'word_p2': "'s",
#   'pos_n2': 'BOS',
#   'pos_n1': 'NNP',
#   'pos': 'NNP',
#   'pos_p1': 'NNP',
#   'pos_p2': 'POS'}]

# %% [markdown]
# This $\mathbf{X}\_{\textrm{dict}}$ is incomplete. For the prediction, we need to reinject dynamically the two previously predicted tags to have the full feature vector. Write this code here.
#
# This part is probably the most difficult of the lab. You may want to write it first for one sentence, and then for the test corpus. The prediction will take a longer time and you may want to include a progress bar with this snippet:
# ```
# from tqdm import tqdm
# for test_sentence in tqdm(test_corpus):
# ```

# %%
y_test_predicted_dyn = []

# %%
def predic(X_test_dict):
    # Vectorize the test sentence and one hot encoding
    X_test = vecc.transform(X_test_dict)
    # Predicts the chunks and returns numbers
    y_test_predicted = clasifierr.predict(X_test)
    return y_test_predicted

# %%
y_test_predicted_dyn = []

X_test_dict, y_test = extract_features_static(test_corpus, w_size, feature_names)  
ypre=[]                     
c1='BOS'
c2='BOS'
X_test_dict[0]['chunk_n2']=c2
X_test_dict[0]['chunk_n1']=c1
pred=predic(X_test_dict[0])
y_test_predicted_dyn.append(pred[0])
#ypre.append(pred[0])
for i in range (1,len(X_test_dict)):
    c2=c1
    
    c1=pred
    
    X_test_dict[i]['chunk_n2']=c2
    X_test_dict[i]['chunk_n1']=c1
    pred=predic(X_test_dict[i])
    y_test_predicted_dyn.append(pred[0])
 #   ypre.append(pred[0])

# %%
y_test_predicted_dyn[:3]
# Out:
# ['B-NP', 'I-NP', 'I-NP']

# %%
inx = 0
for sentence in test_corpus:
    for word in sentence:
        word['pchunk'] = y_test_predicted_dyn[inx]
        inx += 1

# %%
save_results(test_corpus, keys, 'out')

# %% [markdown]
# #### Evaluation

# %%
lines = open('out').read().splitlines()
res = conlleval.evaluate(lines)
improved_ml_score = res['overall']['chunks']['evals']['f1']
improved_ml_score
# Out:
# 0.9263263766658284

# %% [markdown]
# ### Optional improvement

# %% [markdown]
# As an optional task, you can try to improve the score with beam search. If you know this technique, apply it using the probability output of logistic regression.
#
# With the same classifier and a beam diameter of 5, your teacher obtained 92.87.

# %% [markdown]
# ## Collecting the entities

# %% [markdown]
# You will now collect all the named entities from the training set, defined as NP chunks and starting with a `NNP` (proper noun) or a `NNPS` (proper noun, plural) tag. As an example, in the first sentence of `train_corpus`, you will extract `('September', )` and `('July', 'and', 'August')`. You will set all the tuples in a set that you will call `ne_set`.

# %%
train_corpus
# Out:
# [[{'form': 'Confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'widely', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'dive', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'due', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'release', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'tomorrow', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'fail', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'near-record', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'deficits', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Chancellor', 'pos': 'NNP', 'chunk': 'O'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'Exchequer', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Nigel', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'restated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'commitment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'firm', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'helped', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'prevent', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'freefall', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'over', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'past', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'week', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'But', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'analysts', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'reckon', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'underlying', 'pos': 'VBG', 'chunk': 'B-NP'},
#   {'form': 'support', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'been', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'eroded', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'chancellor', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'failure', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'announce', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'any', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'new', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'measures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'his', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'Mansion', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'House', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'speech', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'last', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'Thursday', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'This', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'increased', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'risk', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'government', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'being', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'forced', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'increase', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'base', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'rates', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': '16', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'their', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'current', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': '15', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'level', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'defend', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'economists', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'foreign', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'exchange', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'market', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'analysts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'say', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': '``', 'pos': '``', 'chunk': 'O'},
#   {'form': 'The', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'risks', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'bad', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'figure', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'are', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'very', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'heavily', 'pos': 'RB', 'chunk': 'I-ADVP'},
#   {'form': 'on', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'down', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'side', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': "''", 'pos': "''", 'chunk': 'O'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'Chris', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Dillow', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'senior', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'U.K.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'economist', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'at', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Nomura', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Research', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Institute', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': '``', 'pos': '``', 'chunk': 'O'},
#   {'form': 'If', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'there', 'pos': 'EX', 'chunk': 'B-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'bad', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'number', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'there', 'pos': 'EX', 'chunk': 'B-NP'},
#   {'form': 'could', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'be', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'an', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'awful', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'lot', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'pressure', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': "''", 'pos': "''", 'chunk': 'O'},
#   {'form': 'noted', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'Simon', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Briscoe', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'U.K.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'economist', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Midland', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Montagu', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Midland', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Bank', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'PLC', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Forecasts', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'range', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'widely', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'but', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'few', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'economists', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'expect', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'data', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'very', 'pos': 'RB', 'chunk': 'I-NP'},
#   {'form': 'marked', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'O'},
#   {'form': '#', 'pos': '#', 'chunk': 'O'},
#   {'form': '2', 'pos': 'CD', 'chunk': 'O'},
#   {'form': 'billion', 'pos': 'CD', 'chunk': 'O'},
#   {'form': '-LRB-', 'pos': '(', 'chunk': 'O'},
#   {'form': '$', 'pos': '$', 'chunk': 'B-ADJP'},
#   {'form': '3.2', 'pos': 'CD', 'chunk': 'O'},
#   {'form': 'billion', 'pos': 'CD', 'chunk': 'O'},
#   {'form': '-RRB-', 'pos': ')', 'chunk': 'O'},
#   {'form': 'deficit', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'current', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'account', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'reported', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'The', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'deficit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': '#', 'pos': '#', 'chunk': 'I-NP'},
#   {'form': '2.2', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'billion', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'gap', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'registered', 'pos': 'VBN', 'chunk': 'B-VP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'are', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'topped', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'only', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': '#', 'pos': '#', 'chunk': 'I-NP'},
#   {'form': '2.3', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'billion', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'deficit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'October', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': '1988', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Sanjay', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Joshi', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'European', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'economist', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'at', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Baring', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Brothers', 'pos': 'NNPS', 'chunk': 'I-NP'},
#   {'form': '&', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'there', 'pos': 'EX', 'chunk': 'B-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'no', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sign', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'Britain', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'manufacturing', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'industry', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'transforming', 'pos': 'VBG', 'chunk': 'I-VP'},
#   {'form': 'itself', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'boost', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'exports', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'At', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'same', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'time', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'he', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'remains', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'fairly', 'pos': 'RB', 'chunk': 'B-ADJP'},
#   {'form': 'pessimistic', 'pos': 'JJ', 'chunk': 'I-ADJP'},
#   {'form': 'about', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'outlook', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'imports', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'given', 'pos': 'VBN', 'chunk': 'B-PP'},
#   {'form': 'continued', 'pos': 'VBD', 'chunk': 'B-NP'},
#   {'form': 'high', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'consumer', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'capital', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'goods', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'inflows', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'He', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'reckons', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'current', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'account', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'deficit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'will', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'narrow', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'only', 'pos': 'RB', 'chunk': 'B-NP'},
#   {'form': '#', 'pos': '#', 'chunk': 'I-NP'},
#   {'form': '1.8', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'billion', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'However', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'Mr.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Dillow', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'he', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'believes', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'reduction', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'raw', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'material', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'stockbuilding', 'pos': 'VBG', 'chunk': 'I-NP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'industry', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'could', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'lead', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'drop', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'imports', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Combined', 'pos': 'VBN', 'chunk': 'B-PP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'at', 'pos': 'IN', 'chunk': 'B-ADVP'},
#   {'form': 'least', 'pos': 'JJS', 'chunk': 'I-ADVP'},
#   {'form': 'some', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'rebound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'exports', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'after', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'unexpected', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'decline', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'deficit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'could', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'narrow', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'as', 'pos': 'RB', 'chunk': 'B-NP'},
#   {'form': 'little', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'as', 'pos': 'IN', 'chunk': 'I-NP'},
#   {'form': '#', 'pos': '#', 'chunk': 'I-NP'},
#   {'form': '1.3', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'billion', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Mr.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Briscoe', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'who', 'pos': 'WP', 'chunk': 'B-NP'},
#   {'form': 'also', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'forecasts', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': '#', 'pos': '#', 'chunk': 'I-NP'},
#   {'form': '1.3', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'billion', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'current', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'account', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'gap', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'warns', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'even', 'pos': 'RB', 'chunk': 'B-SBAR'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'I-SBAR'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'are', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'bullish', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'currency', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'wo', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': "n't", 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'advance', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'much', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'because', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'investors', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'will', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'want', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'see', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'further', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'evidence', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'turnaround', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'before', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'adjusting', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'positions', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Nevertheless', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'he', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'noted', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': '``', 'pos': '``', 'chunk': 'O'},
#   {'form': 'No', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'one', 'pos': 'PRP', 'chunk': 'I-NP'},
#   {'form': 'will', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'want', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'go', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'into', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'without', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'flat', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'position', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': "''", 'pos': "''", 'chunk': 'O'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Meanwhile', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'overall', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'evidence', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'on', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'economy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'remains', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'fairly', 'pos': 'RB', 'chunk': 'B-ADJP'},
#   {'form': 'clouded', 'pos': 'VBN', 'chunk': 'I-ADJP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'In', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'his', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'Mansion', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'House', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'speech', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'Mr.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'warned', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'further', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'slowdown', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'can', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'be', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'as', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'impact', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'last', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'rise', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'interest', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'rates', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'earlier', 'pos': 'RBR', 'chunk': 'B-NP'},
#   {'form': 'this', 'pos': 'DT', 'chunk': 'I-NP'},
#   {'form': 'month', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'takes', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'effect', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'U.K.', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'base', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'rates', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'are', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'at', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'their', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'highest', 'pos': 'JJS', 'chunk': 'I-NP'},
#   {'form': 'level', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'eight', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'years', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'But', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'consumer', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'expenditure', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'data', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'released', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'Friday', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'do', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': "n't", 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'suggest', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'U.K.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'economy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'slowing', 'pos': 'VBG', 'chunk': 'I-VP'},
#   {'form': 'that', 'pos': 'DT', 'chunk': 'B-ADVP'},
#   {'form': 'quickly', 'pos': 'RB', 'chunk': 'I-ADVP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'The', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'show', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'DT', 'chunk': 'O'},
#   {'form': 'spending', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'rose', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': '0.1', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'third', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'quarter', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'second', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'quarter', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'was', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'up', 'pos': 'IN', 'chunk': 'B-ADVP'},
#   {'form': '3.8', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'year', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'ago', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'This', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'compares', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': '1.6', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'rise', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'second', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'first', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'quarter', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': '5.4', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'increase', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'second', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'quarter', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1988', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Mr.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Dillow', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'data', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'show', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'economy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '``', 'pos': '``', 'chunk': 'O'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'still', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'quite', 'pos': 'RB', 'chunk': 'B-ADJP'},
#   {'form': 'strong', 'pos': 'JJ', 'chunk': 'I-ADJP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': "''", 'pos': "''", 'chunk': 'O'},
#   {'form': 'but', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'suggestions', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'much', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'spending', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'went', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'on', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'services', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'rather', 'pos': 'RB', 'chunk': 'B-PP'},
#   {'form': 'than', 'pos': 'IN', 'chunk': 'I-PP'},
#   {'form': 'consumer', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'goods', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'should', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'reduce', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'fears', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'more', 'pos': 'JJR', 'chunk': 'B-NP'},
#   {'form': 'import', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'rises', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Certainly', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'chancellor', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'made', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'clear', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'he', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'prepared', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'increase', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'interest', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'rates', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'again', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'necessary', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'both', 'pos': 'DT', 'chunk': 'I-VP'},
#   {'form': 'ensure', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'slowdown', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'does', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'place', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'that', 'pos': 'DT', 'chunk': 'O'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'does', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': "n't", 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'decline', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'further', 'pos': 'JJ', 'chunk': 'B-ADVP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Thursday', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'he', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'reminded', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'his', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'audience', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'government', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '``', 'pos': '``', 'chunk': 'O'},
#   {'form': 'can', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'not', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'allow', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'necessary', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'rigor', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'be', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'undermined', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'exchange', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'rate', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'weakness', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'},
#   {'form': "''", 'pos': "''", 'chunk': 'O'}],
#  [{'form': 'Analysts', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'agree', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'there', 'pos': 'EX', 'chunk': 'B-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'little', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'holding', 'pos': 'NN', 'chunk': 'B-VP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'firm', 'pos': 'NN', 'chunk': 'B-ADJP'},
#   {'form': 'at', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'moment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'other', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'than', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Mr.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'promise', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'rates', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'will', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'be', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'pushed', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'higher', 'pos': 'JJR', 'chunk': 'B-ADJP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'necessary', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'And', 'pos': 'CC', 'chunk': 'O'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'they', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'warn', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'any', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'further', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'drop', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'government', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'popularity', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'could', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'swiftly', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'make', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'this', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'promise', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'sound', 'pos': 'NN', 'chunk': 'B-VP'},
#   {'form': 'hollow', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Sterling', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'was', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'already', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'showing', 'pos': 'VBG', 'chunk': 'I-VP'},
#   {'form': 'some', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'signs', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'lack', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Mr.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'promise', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'Friday', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'In', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'European', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'trading', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'declined', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': '$', 'pos': '$', 'chunk': 'B-NP'},
#   {'form': '1.5890', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': '2.9495', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'marks', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '$', 'pos': '$', 'chunk': 'B-NP'},
#   {'form': '1.5940', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': '2.9429', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'marks', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'late', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'Thursday', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Economists', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'suggested', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'falls', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'much', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'below', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '2.90', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'marks', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'government', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'will', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'be', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'forced', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'increase', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'rates', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': '16', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'both', 'pos': 'DT', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'halt', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'any', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'further', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'decline', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'ensure', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'balance', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'remains', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'unchanged', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Friday', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'Market', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Activity', 'pos': 'NN', 'chunk': 'I-NP'}],
#  [{'form': 'The', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'dollar', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'posted', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'gains', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'quiet', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'trading', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'as', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'concerns', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'about', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'equities', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'abated', 'pos': 'VBN', 'chunk': 'B-VP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Foreign', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'exchange', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'dealers', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'currency', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'market', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'begun', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'distance', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'itself', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'volatile', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'stock', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'exchange', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'which', 'pos': 'WDT', 'chunk': 'B-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'preoccupied', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'market', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'since', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Oct.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': '13', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'when', 'pos': 'WRB', 'chunk': 'B-ADVP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'Dow', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Jones', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Industrial', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Average', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'plunged', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'more', 'pos': 'JJR', 'chunk': 'B-NP'},
#   {'form': 'than', 'pos': 'IN', 'chunk': 'I-NP'},
#   {'form': '190', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'points', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Currency', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'analysts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'predict', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'coming', 'pos': 'VBG', 'chunk': 'I-NP'},
#   {'form': 'week', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'foreign', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'exchange', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'market', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'will', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'shift', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'focus', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'back', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'economic', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'fundamentals', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'keeping', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'close', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'eye', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'out', 'pos': 'IN', 'chunk': 'B-ADVP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'any', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'signs', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'easing', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'U.S.', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Federal', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Reserve', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Late', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'New', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'York', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'trading', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'day', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'dollar', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'was', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'quoted', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'at', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1.8578', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'marks', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'up', 'pos': 'IN', 'chunk': 'B-ADVP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1.8470', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'marks', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'late', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'Thursday', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'New', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'York', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'The', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'U.S.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'currency', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'was', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'also', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'changing', 'pos': 'VBG', 'chunk': 'I-VP'},
#   {'form': 'hands', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'at', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '142.43', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'yen', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'up', 'pos': 'IN', 'chunk': 'B-ADVP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '141.70', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'yen', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'New', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'York', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'late', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'Thursday', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'In', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Tokyo', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'on', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Monday', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
# ...
#   {'form': 'all', 'pos': 'DT', 'chunk': 'O'},
#   {'form': 'have', 'pos': 'NN', 'chunk': 'B-VP'},
#   {'form': 'plans', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'build', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'additional', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'lines', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'such', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'coated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'corrosion-resistant', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'steel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'The', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'surge', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'production', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'analysts', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'say', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'raises', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'questions', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'about', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'capacity', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'outpacing', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'demand', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'They', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'note', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'most', 'pos': 'RBS', 'chunk': 'B-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'new', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'plants', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'will', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'come', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'on', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'line', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1992', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'when', 'pos': 'WRB', 'chunk': 'B-ADVP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'current', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'import', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'restraint', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'program', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'ends', 'pos': 'NNS', 'chunk': 'B-VP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'which', 'pos': 'WDT', 'chunk': 'B-NP'},
#   {'form': 'could', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'result', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'more', 'pos': 'JJR', 'chunk': 'B-NP'},
#   {'form': 'imports', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': '``', 'pos': '``', 'chunk': 'O'},
#   {'form': 'There', 'pos': 'EX', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'too', 'pos': 'RB', 'chunk': 'B-NP'},
#   {'form': 'much', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'capacity', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': "''", 'pos': "''", 'chunk': 'O'},
#   {'form': 'contended', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'Charles', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Bradford', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'an', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'analyst', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Merrill', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lynch', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Capital', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Markets', 'pos': 'NNPS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': '``', 'pos': '``', 'chunk': 'O'},
#   {'form': 'I', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'do', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': "n't", 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'think', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'there', 'pos': 'EX', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'anyone', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'not', 'pos': 'RB', 'chunk': 'B-VP'},
#   {'form': 'building', 'pos': 'VBG', 'chunk': 'I-VP'},
#   {'form': 'one', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'},
#   {'form': "''", 'pos': "''", 'chunk': 'O'}],
#  [{'form': 'He', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'does', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'add', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'however', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'that', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'transplanted', 'pos': 'VBN', 'chunk': 'B-NP'},
#   {'form': 'Japanese', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'car', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'makers', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'are', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'boosting', 'pos': 'VBG', 'chunk': 'I-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'levels', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'U.S.-made', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'steel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'their', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'autos', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'instead', 'pos': 'RB', 'chunk': 'B-PP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'I-PP'},
#   {'form': 'relying', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'heavily', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'on', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'imported', 'pos': 'VBN', 'chunk': 'B-NP'},
#   {'form': 'steel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'That', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'trend', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'could', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'increase', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'demand', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'hot-dipped', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'galvanized', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'sheet', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'The', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'hot-dipped', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'galvanized', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'segment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'one', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'fastest-growing', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'most', 'pos': 'RBS', 'chunk': 'I-NP'},
#   {'form': 'profitable', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'segments', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'steel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'market', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'coveted', 'pos': 'VBN', 'chunk': 'B-VP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'all', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'major', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'integrated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'steelmakers', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'wanting', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'maintain', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'an', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'edge', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'over', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'smaller', 'pos': 'JJR', 'chunk': 'B-NP'},
#   {'form': 'minimills', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'reconstructed', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'mills', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '--', 'pos': ':', 'chunk': 'O'},
#   {'form': 'those', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'spun', 'pos': 'VBN', 'chunk': 'B-VP'},
#   {'form': 'off', 'pos': 'IN', 'chunk': 'B-PRT'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'employees', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Indeed', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'USX', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'expects', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'market', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'coated', 'pos': 'VBN', 'chunk': 'B-NP'},
#   {'form': 'sheet', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'steel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'reach', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': '12', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'million', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'tons', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'annually', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1992', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'compared', 'pos': 'VBN', 'chunk': 'B-PP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '10.2', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'million', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'tons', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'shipped', 'pos': 'VBN', 'chunk': 'B-VP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1988', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'For', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'first', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'eight', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'months', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1989', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'analysts', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'say', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': 'shipments', 'pos': 'NNS', 'chunk': 'B-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'hot-dipped', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'galvanized', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'steel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'increased', 'pos': 'VBN', 'chunk': 'B-VP'},
#   {'form': 'about', 'pos': 'IN', 'chunk': 'B-NP'},
#   {'form': '8', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'year', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'earlier', 'pos': 'RBR', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'while', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'overall', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'steel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'shipments', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'were', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'up', 'pos': 'IN', 'chunk': 'B-ADVP'},
#   {'form': 'only', 'pos': 'RB', 'chunk': 'B-NP'},
#   {'form': '2.4', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'USX', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'Kobe', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Steel', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'hope', 'pos': 'NN', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'reach', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'definitive', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'establishing', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': '50-50', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'partnership', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'end', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'year', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'construction', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'tentatively', 'pos': 'RB', 'chunk': 'B-VP'},
#   {'form': 'slated', 'pos': 'VBD', 'chunk': 'I-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'spring', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1990', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'production', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1992', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'USX', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'already', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'six', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'lines', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'existing', 'pos': 'VBG', 'chunk': 'B-NP'},
#   {'form': 'plants', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'producing', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'hot-dipped', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'galvanized', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'steel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'but', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'this', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'marks', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'first', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'so-called', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'greenfield', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'plant', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'such', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'production', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Moreover', 'pos': 'RB', 'chunk': 'B-ADVP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'will', 'pos': 'MD', 'chunk': 'B-VP'},
#   {'form': 'boost', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'by', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '50', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': '%', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'USX', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'current', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'hot-dipped', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'capacity', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': '1,275,000', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'tons', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  ...]

# %% [markdown]
# You can write a two-pass procedure. For each sentence of the corpus:
# 1. In the first pass, you will collect the start indices of the noun groups which are also proper nouns. For the first sentence, it will result in the list `[16, 30]`;
# 2. In the second pass, you will collect the segments, starting at each index. For the first sentence, it will result in the tuples `('September',)`and `('July', 'and', 'August')`
#
# Should you have a better solution, please use it.

# %%
ne_set=[]
for corpuss in train_corpus:
    ind=[]
    for i in range(len(corpuss)):       
            if (corpuss[i]['pos']=='NNP'or corpuss[i]['pos']=='NNPS') and corpuss[i]['chunk']=='B-NP' :
                ind.append(i)  
    for j in ind:
        temp2=[]
        temp=corpuss[j]['form']
        temp2.append(temp)
        k=j+1
        while k <(len(corpuss)) and corpuss[k]['chunk']=='I-NP':
            temp2.append(corpuss[k]['form'])
            k+=1 
        ne_set.append(tuple(temp2))
ne_set=set(ne_set)

# %%
len(ne_set)
# Out:
# 4348

# %% [markdown]
# ### Creating a small set

# %% [markdown]
# To run the subsequent experiments faster, you will limit the dataset to the entities starting with letter _K_. I chose this letter, because it corresponded to one of the smallest sets. You will call the resulting set: `ne_small_set`. Feel free to use the full set after you have completed this assignment.

# %%
ne_small_set=set()
for ne in ne_set:
    if ne[0][0].lower()=='k':
        ne_small_set.add(ne)

# %%
list(sorted(ne_set))[:25]
# Out:
# [('1-2-3', 'Release', '3'),
#  ('67-year-old', 'Mrs.', 'Thi'),
#  ('A.', 'Foster', 'Higgins', '&', 'Co.'),
#  ('A.', 'Schulman'),
#  ('A.F.', 'Delchamps', 'Jr.'),
#  ('A.G.', 'Edwards', '&', 'Sons', 'Inc.'),
#  ('A.P.', 'Green'),
#  ('A.P.', 'Green', 'Industries'),
#  ('A.P.', 'Green', 'Industries', 'Inc.'),
#  ('ABC',),
#  ('AC&R', 'ADVERTISING'),
#  ('AC&R', 'Advertising'),
#  ('AC&R\\/CCL', 'Advertising'),
#  ('ADN',),
#  ('AEW',),
#  ('AGS', 'Computers'),
#  ('AMR',),
#  ('AMR', 'Corp.'),
#  ('AMR', 'shareholders'),
#  ('AMRO', 'Bank'),
#  ('ANB', 'Investment', 'Management', 'Co.'),
#  ('AON',),
#  ('ARA', 'Services', 'Inc.'),
#  ('ARCO',),
#  ('ARTY', 'FAX')]

# %%
sorted(ne_small_set)
# Out:
# [('K', 'mart', 'Corp.', 'Chairman', 'Joseph', 'E.', 'Antonini'),
#  ('K-H', 'Corp.'),
#  ('KIM',),
#  ('KLM', 'Royal', 'Dutch', 'Airlines'),
#  ('KPMG', 'Peat', 'Marwick'),
#  ('KTXL',),
#  ('Kabul',),
#  ('Kacy', 'McClelland'),
#  ('Kaitaia',),
#  ('Kajima',),
#  ('Kansas',),
#  ('Kansas', 'Power'),
#  ('Kansas', 'and', 'Texas'),
#  ('Karen', 'Olshan'),
#  ('Kary', 'Moss'),
#  ('Kasler', 'Corp.'),
#  ('Kate', 'Michelman'),
#  ('Kathe', 'Dillmann'),
#  ('Kathie', 'Huff'),
#  ('Kathie', 'Roberts'),
#  ('Kathryn', 'McGrath'),
#  ('Kathy', 'Stanwick'),
#  ('Katonah',),
#  ('Kawasaki', 'Steel'),
#  ('Ke', 'Zaishuo'),
#  ('Kean', 'forces'),
#  ('Keefe', ',', 'Bruyette', '&', 'Woods', 'Inc.'),
#  ('Keihin', 'Electric', 'Express', 'Railway', 'Co'),
#  ('Keith', 'L.', 'Fogg'),
#  ('Keith', 'Mulrooney'),
#  ('Keizaikai',),
#  ('Keizaikai', 'Corp.'),
#  ('Kemper',),
#  ('Kenneth', 'A.', 'Eldred'),
#  ('Kenneth', 'Abraham'),
#  ('Kenneth', 'H.', 'Olsen'),
#  ('Kenneth', 'T.', 'Rosen'),
#  ('Kent', 'Neal'),
#  ('Kenton',),
#  ('Kentucky',),
#  ('Kentucky', 'Fried', 'Chicken', 'stores'),
#  ('Kevin', 'Logan'),
#  ('Khmer', 'Rouge', 'camps'),
#  ('Khost',),
#  ('Kidder', ',', 'Peabody', '&', 'Co'),
#  ('Kidder', ',', 'Peabody', '&', 'Co.'),
#  ('Kidder', 'Peabody'),
#  ('Kim', 'Schwartz'),
#  ('Kimberly', 'Ann', 'Smith'),
#  ('King', 'Broadcasting', 'Co.'),
#  ('Kinney', 'and', 'Foot', 'Locker', 'shoe', 'stores'),
#  ('Kirin',),
#  ('Kirin', 'Brewery'),
#  ('Kitchen',),
#  ('Kleinwort', 'Benson', 'Government', 'Securities', 'Inc.'),
#  ('Kleinwort', 'Benson', 'North', 'America'),
#  ('Knoxville',),
#  ('Ko', 'Shioya'),
#  ('Kobe', 'Steel'),
#  ('Kobe', 'Steel', 'Ltd.'),
#  ('Kodak',),
#  ('Kollmorgen',),
#  ('Kraft', 'General', 'Foods'),
#  ('Kremlin', 'wrangling'),
#  ('Krenz',),
#  ('Kringle', 'fares'),
#  ('Kroger', 'Co'),
#  ('Kuala', 'Lumpur'),
#  ('Kumagai-Gumi',),
#  ('Kurds',),
#  ('Kursk', 'and', 'Smolensk'),
#  ('Kurt', 'Hager'),
#  ('Kwek', 'Hong', 'Png'),
#  ('Ky',),
#  ('Ky.',),
#  ('Kyocera',)]

# %% [markdown]
# ## Resolving the entities

# %% [markdown]
# You will now implement a simple method to find the named entities from the previous exercise in Wikipedia and Wikidata.

# %% [markdown]
# First, look at a few entities in your set and find:
# 1. a few entities that you think are in wikipedia,
# 2. entities that will not be in wikipedia, and
# 3. entities that you think are ambiguous: An entity that may correspond to two or more things.
#
# You will describe your findings in the report.

# %% [markdown]
# ### A function to lookup entities

# %% [markdown]
# Read the function below and try to understand what it means. You will describe it in your report.

# %%
def wikipedia_lookup(ner, base_url='https://en.wikipedia.org/wiki/'):
    try:
        url_en = base_url + ' '.join(ner)
        html_doc = requests.get(url_en).text
        parse_tree = bs4.BeautifulSoup(html_doc, 'html.parser')
        entity_id = parse_tree.find("a", {"accesskey": "g"})['href']
        head_id, entity_id = os.path.split(entity_id)
        return entity_id
    except:
        pass
        # print('Not found in: ', base_url)
    entity_id = 'UNK'
    return entity_id

# %% [markdown]
# Write a function to run the lookup and keep the resolved entities (only the resolved entities). You will call it `ne_ids_en`

# %%
from tqdm import tqdm
ne_ids_en=[]
for w in tqdm(sorted(ne_small_set)):
    if wikipedia_lookup(w)!='UNK':
        ne_ids_en.append((w,wikipedia_lookup(w)))
# Out:
# 100%|██████████| 76/76 [02:53<00:00,  2.29s/it]

# %%
ne_ids_en
# Out:
# [(('KIM',), 'Q224736'),
#  (('KLM', 'Royal', 'Dutch', 'Airlines'), 'Q181912'),
#  (('KPMG', 'Peat', 'Marwick'), 'Q493751'),
#  (('KTXL',), 'Q6339344'),
#  (('Kabul',), 'Q5838'),
#  (('Kaitaia',), 'Q257417'),
#  (('Kajima',), 'Q1081154'),
#  (('Kansas',), 'Q1558'),
#  (('Kate', 'Michelman'), 'Q785671'),
#  (('Katonah',), 'Q2888777'),
#  (('Kawasaki', 'Steel'), 'Q6379829'),
#  (('Kemper',), 'Q126993'),
#  (('Kenneth', 'Abraham'), 'Q59268486'),
#  (('Kenneth', 'H.', 'Olsen'), 'Q454315'),
#  (('Kenton',), 'Q358393'),
#  (('Kentucky',), 'Q1603'),
#  (('Khost',), 'Q386682'),
#  (('Kidder', 'Peabody'), 'Q3196386'),
#  (('Kirin',), 'Q297659'),
#  (('Kirin', 'Brewery'), 'Q13403399'),
#  (('Kitchen',), 'Q43164'),
#  (('Knoxville',), 'Q185582'),
#  (('Kobe', 'Steel'), 'Q1730802'),
#  (('Kodak',), 'Q486269'),
#  (('Kraft', 'General', 'Foods'), 'Q327751'),
#  (('Krenz',), 'Q21512656'),
#  (('Kuala', 'Lumpur'), 'Q1865'),
#  (('Kurds',), 'Q12223'),
#  (('Kurt', 'Hager'), 'Q95367'),
#  (('Kwek', 'Hong', 'Png'), 'Q10559663'),
#  (('Ky',), 'Q225951'),
#  (('Ky.',), 'Q225951'),
#  (('Kyocera',), 'Q745099')]

# %% [markdown]
# Sometimes, entities need a confirmation. You will apply the resolution with the Swedish wikipedia.

# %%
from tqdm import tqdm
ne_ids_sv=[]
for w in tqdm(sorted(ne_small_set)):
    idd=wikipedia_lookup(w,'https://sv.wikipedia.org/wiki/')
    if id !='UNK':
        ne_ids_sv.append((w,idd))
# Out:
# 100%|██████████| 76/76 [00:09<00:00,  7.70it/s]

# %%
ne_ids_sv
# Out:
# [(('K', 'mart', 'Corp.', 'Chairman', 'Joseph', 'E.', 'Antonini'), 'UNK'),
#  (('K-H', 'Corp.'), 'UNK'),
#  (('KIM',), 'Q224736'),
#  (('KLM', 'Royal', 'Dutch', 'Airlines'), 'Q181912'),
#  (('KPMG', 'Peat', 'Marwick'), 'UNK'),
#  (('KTXL',), 'UNK'),
#  (('Kabul',), 'Q5838'),
#  (('Kacy', 'McClelland'), 'UNK'),
#  (('Kaitaia',), 'UNK'),
#  (('Kajima',), 'UNK'),
#  (('Kansas',), 'Q1558'),
#  (('Kansas', 'Power'), 'UNK'),
#  (('Kansas', 'and', 'Texas'), 'UNK'),
#  (('Karen', 'Olshan'), 'UNK'),
#  (('Kary', 'Moss'), 'UNK'),
#  (('Kasler', 'Corp.'), 'UNK'),
#  (('Kate', 'Michelman'), 'UNK'),
#  (('Kathe', 'Dillmann'), 'UNK'),
#  (('Kathie', 'Huff'), 'UNK'),
#  (('Kathie', 'Roberts'), 'UNK'),
#  (('Kathryn', 'McGrath'), 'UNK'),
#  (('Kathy', 'Stanwick'), 'UNK'),
#  (('Katonah',), 'UNK'),
#  (('Kawasaki', 'Steel'), 'UNK'),
#  (('Ke', 'Zaishuo'), 'UNK'),
#  (('Kean', 'forces'), 'UNK'),
#  (('Keefe', ',', 'Bruyette', '&', 'Woods', 'Inc.'), 'UNK'),
#  (('Keihin', 'Electric', 'Express', 'Railway', 'Co'), 'UNK'),
#  (('Keith', 'L.', 'Fogg'), 'UNK'),
#  (('Keith', 'Mulrooney'), 'UNK'),
#  (('Keizaikai',), 'UNK'),
#  (('Keizaikai', 'Corp.'), 'UNK'),
#  (('Kemper',), 'UNK'),
#  (('Kenneth', 'A.', 'Eldred'), 'UNK'),
#  (('Kenneth', 'Abraham'), 'UNK'),
#  (('Kenneth', 'H.', 'Olsen'), 'UNK'),
#  (('Kenneth', 'T.', 'Rosen'), 'UNK'),
#  (('Kent', 'Neal'), 'UNK'),
#  (('Kenton',), 'Q358393'),
#  (('Kentucky',), 'Q1603'),
#  (('Kentucky', 'Fried', 'Chicken', 'stores'), 'UNK'),
#  (('Kevin', 'Logan'), 'UNK'),
#  (('Khmer', 'Rouge', 'camps'), 'UNK'),
#  (('Khost',), 'Q386682'),
#  (('Kidder', ',', 'Peabody', '&', 'Co'), 'UNK'),
#  (('Kidder', ',', 'Peabody', '&', 'Co.'), 'UNK'),
#  (('Kidder', 'Peabody'), 'UNK'),
#  (('Kim', 'Schwartz'), 'UNK'),
#  (('Kimberly', 'Ann', 'Smith'), 'UNK'),
#  (('King', 'Broadcasting', 'Co.'), 'UNK'),
#  (('Kinney', 'and', 'Foot', 'Locker', 'shoe', 'stores'), 'UNK'),
#  (('Kirin',), 'Q297659'),
#  (('Kirin', 'Brewery'), 'UNK'),
#  (('Kitchen',), 'Q952431'),
#  (('Kleinwort', 'Benson', 'Government', 'Securities', 'Inc.'), 'UNK'),
#  (('Kleinwort', 'Benson', 'North', 'America'), 'UNK'),
#  (('Knoxville',), 'Q232749'),
#  (('Ko', 'Shioya'), 'UNK'),
#  (('Kobe', 'Steel'), 'UNK'),
#  (('Kobe', 'Steel', 'Ltd.'), 'UNK'),
#  (('Kodak',), 'Q486269'),
#  (('Kollmorgen',), 'UNK'),
#  (('Kraft', 'General', 'Foods'), 'Q12857502'),
#  (('Kremlin', 'wrangling'), 'UNK'),
#  (('Krenz',), 'UNK'),
#  (('Kringle', 'fares'), 'UNK'),
#  (('Kroger', 'Co'), 'Q153417'),
#  (('Kuala', 'Lumpur'), 'Q1865'),
#  (('Kumagai-Gumi',), 'UNK'),
#  (('Kurds',), 'UNK'),
#  (('Kursk', 'and', 'Smolensk'), 'UNK'),
#  (('Kurt', 'Hager'), 'UNK'),
#  (('Kwek', 'Hong', 'Png'), 'UNK'),
#  (('Ky',), 'UNK'),
#  (('Ky.',), 'UNK'),
#  (('Kyocera',), 'UNK')]

# %% [markdown]
# You will compute the intersection of the two sets. You will assign it to a list that you will sort and that you will call: `confirmed_ne_en_sv`.

# %%
confirmed_ne_en_sv= sorted(set(ne_ids_sv).intersection(set(ne_ids_en)))

# %%
confirmed_ne_en_sv
# Out:
# [(('KIM',), 'Q224736'),
#  (('KLM', 'Royal', 'Dutch', 'Airlines'), 'Q181912'),
#  (('Kabul',), 'Q5838'),
#  (('Kansas',), 'Q1558'),
#  (('Kenton',), 'Q358393'),
#  (('Kentucky',), 'Q1603'),
#  (('Khost',), 'Q386682'),
#  (('Kirin',), 'Q297659'),
#  (('Kodak',), 'Q486269'),
#  (('Kuala', 'Lumpur'), 'Q1865')]

# %% [markdown]
# The first items in your list should look like:
# ```
# [(('KIM',), 'Q224736'),
#  (('KLM', 'Royal', 'Dutch', 'Airlines'), 'Q181912'),
#  ...
# ]
# ```

# %% [markdown]
# ## Submission

# %% [markdown]
# When you have written all the code and run all the cells, fill in your ID and as well as the name of the notebook.

# %%
STIL_ID = ["da20exampl-s", "ad02exampl-z"] # Write your stil ids as a list
CURRENT_NOTEBOOK_PATH = os.path.join(os.getcwd(), 
                                     "4-chunker_solution.ipynb") # Write the name of your notebook

# %% [markdown]
# The submission code will send your answer. It consists of the baseline score, the improved machine-learning score, and the confirmed entities.

# %%
import json
ANSWER = json.dumps({'baseline_score': baseline_score,
                    'improved_ml_score': improved_ml_score,
                    'confirmed_ne_en_sv': confirmed_ne_en_sv})
ANSWER

# %% [markdown]
# Now the moment of truth:
# 1. Save your notebook and
# 2. Run the cells below

# %%
SUBMISSION_NOTEBOOK_PATH = CURRENT_NOTEBOOK_PATH + ".submission.bz2"

# %%
import bz2
ASSIGNMENT = 4
API_KEY = "f581ba347babfea0b8f2c74a3a6776a7"

# Copy and compress current notebook
with bz2.open(SUBMISSION_NOTEBOOK_PATH, mode="wb") as fout:
    with open(CURRENT_NOTEBOOK_PATH, "rb") as fin:
        fout.write(fin.read())

# %%
res = requests.post("https://vilde.cs.lth.se/edan20checker/submit", 
                    files={"notebook_file": open(SUBMISSION_NOTEBOOK_PATH, "rb")}, 
                    data={
                        "stil_id": STIL_ID,
                        "assignment": ASSIGNMENT,
                        "answer": ANSWER,
                        "api_key": API_KEY,
                    },
               verify=True)

# from IPython.display import display, JSON
res.json()
# Out:
# {'msg': None,
#  'status': 'correct',
#  'signature': '44d25dade9b27ca3958bb540a9c4162853e05c9858a8d72dedfcc3847fa253f493793ac464ec821aa9e51f2b3d36799d67ce93183182c1a0d001969f313f6682',
#  'submission_id': 'ba27ca6b-e185-4bd0-a357-47c2ed817e68'}

# %% [markdown]
# ## Reading

# %% [markdown]
# You will read the article, <a href="https://www.aclweb.org/anthology/C18-1139"><i>Contextual String
#             Embeddings for Sequence Labeling</i></a> by Akbik et al. (2018)
#             and you will outline the main differences between their system and yours. A LSTM is a type of
#             recurrent neural network, while CRF is a sort of beam search. You will tell the performance
#             they reach on the corpus you used in this laboratory.
